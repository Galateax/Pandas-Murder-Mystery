# %% [markdown]
# ## `Actividades preliminares`

# %% [markdown]
# Comenzamos importando la libreria de pandas

# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Cargamos el dataset que utilizaran durante la investigacion

# %%
crime_scene_report     = pd.read_csv("./_src/datasets/Crime Scene report.csv")
drivers_license        = pd.read_csv("./_src/datasets/Drivers license.csv")
facebook_event_checkin = pd.read_csv("./_src/datasets/facebook_event_checkin.csv")
getfitnow_checkin      = pd.read_csv("./_src/datasets/GetFitNow check in.csv")
getfitnow_members      = pd.read_csv("./_src/datasets/GetFitNow members.csv")
income                 = pd.read_csv("./_src/datasets/income.csv")
interview              = pd.read_csv("./_src/datasets/Interviews.csv")
person                 = pd.read_csv("./_src/datasets/Person.csv")

# %% [markdown]
# Veamos un poco como estan conformados estos dataframes

# %%
# Usamos .info() para ver una descripcion general del dataset, como sus tipos de datos en cada columna y si presenta nulos
crime_scene_report.info()
#Podes cambiar el dataset para ver la informacion general del que quieras
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1228 entries, 0 to 1227
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         1228 non-null   object
#  1   Type         1228 non-null   object
#  2   Description  939 non-null    object
#  3   City         1228 non-null   object
# dtypes: object(4)
# memory usage: 38.5+ KB

# %%
crime_scene_report.head(3)
# Out:
#          Date       Type Description        City
# 0  2017-01-07  smuggling         NaN    Savannah
# 1  2017-01-11     murder         NaN  Springdale
# 2  2017-01-12  smuggling         NaN   Melbourne

# %% [markdown]
# ## `Comenzamos la investigacion`

# %% [markdown]
# ### Un crimen ha ocurrido y el detective necesita tu ayuda.

# %% [markdown]
# #### Pero antes, veamos un diagrama de esquema para ver como estan conectados todos los dataframes
#
# <img src="./_src/schemeboard.png">
#
#
# ### Te entregaron el informe del lugar del crimen, pero de alguna manera lo perdiste. Recordas vagamente que el crimen fue un ​asesinato​ que ocurrió en algún momento el ​15 de enero de 2018​ y que tuvo lugar en ​Pandas City​. **Te recomiendo comenzar por recuperar el informe correspondiente de su respectivo dataframe**

# %%
crime_scene_report.loc[crime_scene_report['Date'] == '2018-01-15'].loc[crime_scene_report['City'] == 'Pandas City']
# Out:
#             Date     Type  \
# 781   2018-01-15   murder
# 1000  2018-01-15  assault
# 1001  2018-01-15  assault
#
#                                                                                                                                                                                     Description  \
# 781   Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
# 1000                                                                                                                Hamilton: Lee, do you yield? Burr: You shot him in the side! Yes he yields!
# 1001                                                                                                                                                                           Report Not Found
#
#              City
# 781   Pandas City
# 1000  Pandas City
# 1001  Pandas City

# %% [markdown]
# hubo dos testigos. el primero vive en la ultima casa en "Northwestern Dr". El segundo testigo se llama Annabel, y vive en "Franklin Ave".

# %%
Sospechoso1 = person.iloc[499]
print(Sospechoso1)
# Out:
# Id                               14887
# Name                    Morty Schapiro
# License_Id                      118009
# Address_Number                    4919
# Address_Street_Name    Northwestern Dr
# Ssn                          111564949
# Name: 499, dtype: object

# %%
person.loc[person['Address_Street_Name'] == "Northwestern Dr"].sort_values(by='Address_Number', ascending=False)
# Out:
#          Id                  Name  License_Id  Address_Number  \
# 499   14887        Morty Schapiro      118009            4919
# 811   17729        Lasonya Wildey      439686            3824
# 4886  53890        Sophie Tiberio      957671            3755
# 7040  73368        Torie Thalmann      773862            3697
# 9609  96595         Coretta Cubie      303645            3631
# 1021  19420           Cody Schiel      890431            3524
# 9272  93509        Emmitt Aceuedo      916706            3491
# 8608  87456   Leonora Wolfsberger      215868            3483
# 2871  36378        Freddie Ellzey      267882            3449
# 4806  53076           Boris Bijou      664914            3327
# 1981  28360        Rashad Cascone      924517            3212
# 1426  23044          Val Portlock      924989            3143
# 4595  51114     Christena Saffell      814284            3055
# 6476  68690            Yer Modest      852404            3046
# ...

# %%
person.loc[person['Name'].str.contains('Annabel', case=False)]
# Out:
#          Id                Name  License_Id  Address_Number  \
# 665   16371      Annabel Miller      490173             103
# 7601  78354      Annabell Siona      158932             978
# 7650  78799  Annabell Droneburg      984316            1944
# 8509  86541   Annabell Zwilling      709133            1859
#
#      Address_Street_Name        Ssn
# 665         Franklin Ave  318771143
# 7601       Whitewater Dr  800278294
# 7650        W Natalie Dr  478793500
# 8509            Patti Rd  332961158

# %%
Sospechoso2 = person.iloc[665]
Sospechoso2
# Out:
# Id                              16371
# Name                   Annabel Miller
# License_Id                     490173
# Address_Number                    103
# Address_Street_Name      Franklin Ave
# Ssn                         318771143
# Name: 665, dtype: object

# %%
interview.head(3)
# Out:
#    Person_Id Transcript
# 0      63713        NaN
# 1      33856        NaN
# 2      82799        NaN

# %%
interview.loc[interview['Person_Id'] == 16371]
# Out:
#       Person_Id  \
# 4989      16371
#
#                                                                                                                  Transcript
# 4989  I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %%
interview.loc[interview['Person_Id'] == 14887]
# Out:
#       Person_Id  \
# 4988      14887
#
#                                                                                                                                                                                                                            Transcript
# 4988  I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".

# %% [markdown]
# numero de miembro comienza con '48Z' y el auto implicado incluye ' H42W'

# %%
getfitnow_members.head(3)
# Out:
#       Id  Person_Id               Name Membership_Start_Date Membership_Status
# 0  NL318      65076    Everette Koepke            2017-09-26              Gold
# 1  0YJ24      80651     Waneta Wellard            2017-12-06              Gold
# 2  5Y28Y      15218  Millicent Yessios            2018-02-05              Gold

# %%
getfitnow_members.loc[getfitnow_members['Id'].str.contains('48Z', case=False)]
# Out:
#         Id  Person_Id           Name Membership_Start_Date Membership_Status
# 65   48Z7A      28819   Joe Germuska            2016-03-05              Gold
# 66   48Z55      67318  Jeremy Bowers            2016-01-01              Gold
# 165  48Z38      49550  Tomas Baisley            2017-02-03            Silver

# %%
getfitnow_checkin.head(3)
# Out:
#   Membership_Id Check_In_Date  Check_In_Time  Check_Out_Time
# 0         NL318    2018-02-12            329             365
# 1         NL318    2017-08-11            469             920
# 2         NL318    2018-04-29            506             554

# %%
getfitnow_checkin.loc[(getfitnow_checkin['Check_In_Date'] == '2018-01-09') & (getfitnow_checkin['Membership_Id'].str.contains('48Z', case=False))]
# Out:
#      Membership_Id Check_In_Date  Check_In_Time  Check_Out_Time
# 2700         48Z7A    2018-01-09           1600            1730
# 2701         48Z55    2018-01-09           1530            1700

# %%
interview.loc[interview['Person_Id'] == 67318]
# Out:
#       Person_Id  \
# 4990      67318
#
#                                                                                                                                                                                                                                             Transcript
# 4990  I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017.

# %% [markdown]
# ## Si creen que encontraron al asesino, ejecuten el siguiente codigo con el posible sospechoso
#
#  Por favor, tene en cuenta que es recomendable no acceder al archivo "asesino.py" para evitar revelar detalles importantes de la caso. Si deseas disfrutar plenamente de la experiencia sin spoilers, te sugiero que evites examinar dicho archivo."

# %%
from asesino import solucion
solucion("Jeremy Bowers")
# Out:
# ¡Felicidades, encontraste al asesino! Pero espera, hay más...
#  Si crees que estas preparado para un desafío, segui investigando
#  la transcripcion del asesino para encontrar al verdadero villano detrás de este crimen

# %%
facebook_event_checkin.head(3)
# Out:
#    person_id  event_id  \
# 0      28508      5880
# 1      63713      3865
# 2      63713      3999
#
#                                                               event_name  \
# 0                      Nudists are people who wear one-button suits.\r\n
# 1  but that's because it's the best book on anything for the layman.\r\n
# 2                             If Murphy's Law can go wrong, it will.\r\n
#
#        date
# 0  20170913
# 1  20171009
# 2  20170502

# %%
SQL = facebook_event_checkin.loc[(facebook_event_checkin['event_name'].str.contains('SQL Symphony Concert') ) & (facebook_event_checkin['date'].astype(str).str.contains('201712'))]

# %%
SQL['person_id'].value_counts()
# Out:
# person_id
# 24556    3
# 99716    3
# 28582    2
# 62596    1
# 19260    1
# 58898    1
# 69699    1
# 19292    1
# 43366    1
# 92343    1
# 81526    1
# 24397    1
# 11173    1
# 79312    1
# 69325    1
# 67318    1
# Name: count, dtype: int64

# %%
person.head(3)
# Out:
#       Id                 Name  License_Id  Address_Number Address_Street_Name  \
# 0  10000   Christoper Peteuil      993845             624        Bankhall Ave
# 1  10007  Kourtney Calderwood      861794            2791       Gustavus Blvd
# 2  10010            Muoi Cary      385336             741     Northwestern Dr
#
#          Ssn
# 0  747714076
# 1  477972044
# 2  828638512

# %%
person.loc[person['Id'] == 99716]
# Out:
#          Id              Name  License_Id  Address_Number Address_Street_Name  \
# 9985  99716  Miranda Priestly      202298            1883          Golden Ave
#
#             Ssn
# 9985  987756388

# %%
drivers_license.head(2)
# Out:
#        Id  Age  Height Eye_Color Hair_Color  Gender Plate_Number Car_Make  \
# 0  103138   37      65     brown     Blonde    Male       T6TV0T     Ford
# 1  103260   22      59     brown     Blonde  Female       G67F83     Ford
#
#   Car_Model
# 0     Focus
# 1      E250

# %%
drivers_license.loc[drivers_license['Id'] == 202298]
# Out:
#           Id  Age  Height Eye_Color Hair_Color  Gender Plate_Number Car_Make  \
# 6883  202298   68      66     green        Red  Female       500123    Tesla
#
#      Car_Model
# 6883   Model S
